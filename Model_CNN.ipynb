# %% [markdown]
# <a href="https://colab.research.google.com/github/anatorres09/DE-MRI_Classificacio_CNN/blob/main/Model_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Connectar a Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Importar llibreries
import os
import cv2
import numpy as np
from glob import glob
import tensorflow as tf
from collections import Counter
from tabulate import tabulate

# %%
# Carregar i preprocés d'imatges per a la predicció
ruta_carpeta = '/content/drive/MyDrive/CNN'

# Ruta del model
ruta_model = os.path.join(ruta_carpeta, "model_CNN.h5")

# Carregar el model
model = tf.keras.models.load_model(ruta_model)

ruta_carpeta_test = os.path.join(ruta_carpeta, "test")
redimensionar_imatge = (128, 128)

# Funció per a recollir les imatges
def recollir_imatges(ruta_carpeta, redimensionar_imatge):
    casos = [nom_carpeta for nom_carpeta in os.listdir(ruta_carpeta) if os.path.isdir(os.path.join(ruta_carpeta, nom_carpeta))]

    imatges = []
    noms_fitxers = []

    for cas in casos:
        ruta_cas = os.path.join(ruta_carpeta, cas)
        rutes_imatges = glob(os.path.join(ruta_cas, '*.png'))

        for ruta_imatge in rutes_imatges:
            imatge = cv2.imread(ruta_imatge)
            imatge = cv2.cvtColor(imatge, cv2.COLOR_BGR2RGB)
            
            # Redimensionar les imatges
            imatge = cv2.resize(imatge, redimensionar_imatge)

            # Obtener el nombre de la subcarpeta y el nombre de la imagen
            num_cas = os.path.basename(ruta_cas)
            num_tall = os.path.basename(ruta_imatge)
            
            
            imatges.append(imatge)
            noms_fitxers.append(f"{num_cas}.{num_tall}")

    return imatges, noms_fitxers

# Recollir imatges de la carpeta de prova
imatges_test, noms_fitxers = recollir_imatges(ruta_carpeta_test, redimensionar_imatge)

# Convertir la llista d'imatges en una matriu numpy
matriu_imatges_test = np.array(imatges_test, dtype='float32')

print(f"S'han recollit {matriu_imatges_test.shape[0]} imatges en total.")
# Out:
# S'han recollit 334 imatges en total.

# %%
# Realitzar la predicció utilitzant el model carregat
predicciones = model.predict(matriu_imatges_test)

# Obtindre les classes predites ('normal' o 'patologic')
classes_predites = np.argmax(predicciones, axis=1)

# Obtindre les probabilitats màximes
probabilidades_maximas = np.max(predicciones, axis=1)

# Calcular umbral dinàmic en funció de la probabilitat màxima
umbral = np.mean(probabilidades_maximas)

# Imprimir les classes predites per a cada imatge en la carpeta de prova
for i in range(matriu_imatges_test.shape[0]):
    nom_fitxer = os.path.basename(noms_fitxers[i])
    classe_predita = classes_predites[i]
   
    if classe_predita == 0:
        classe = 'normal'
    else:
        classe = 'patologic'
    
    print(f"La classe predita per a la imatge {nom_fitxer} és: {classe}")
# Out:
# 11/11 [==============================] - 7s 16ms/step
# La classe predita per a la imatge 0_Case_113.tall_0.png és: normal
# La classe predita per a la imatge 0_Case_113.tall_1.png és: normal
# La classe predita per a la imatge 0_Case_113.tall_2.png és: normal
# La classe predita per a la imatge 0_Case_113.tall_3.png és: normal
# La classe predita per a la imatge 0_Case_113.tall_4.png és: normal
# La classe predita per a la imatge 0_Case_113.tall_5.png és: normal
# La classe predita per a la imatge 0_Case_113.tall_6.png és: normal
# La classe predita per a la imatge 0_Case_113.tall_7.png és: normal
# La classe predita per a la imatge 0_Case_137.tall_0.png és: patologic
# La classe predita per a la imatge 0_Case_137.tall_1.png és: patologic
# La classe predita per a la imatge 0_Case_137.tall_2.png és: patologic
# La classe predita per a la imatge 0_Case_137.tall_3.png és: patologic
# La classe predita per a la imatge 0_Case_137.tall_4.png és: patologic
# La classe predita per a la imatge 0_Case_137.tall_5.png és: patologic
# La classe predita per a la imatge 0_Case_137.tall_6.png és: patologic
# La classe predita per a la imatge 0_Case_106.tall_0.png és: normal
# La classe predita per a la imatge 0_Case_106.tall_1.png és: normal
# La classe predita per a la imatge 0_Case_106.tall_2.png és: normal
# La classe predita per a la imatge 0_Case_106.tall_3.png és: normal
# La classe predita per a la imatge 0_Case_106.tall_4.png és: normal
# La classe predita per a la imatge 0_Case_106.tall_5.png és: normal
# La classe predita per a la imatge 0_Case_106.tall_6.png és: normal
# La classe predita per a la imatge 0_Case_106.tall_7.png és: patologic
# La classe predita per a la imatge 0_Case_114.tall_0.png és: patologic
# La classe predita per a la imatge 0_Case_114.tall_1.png és: patologic
# La classe predita per a la imatge 0_Case_114.tall_2.png és: patologic
# La classe predita per a la imatge 0_Case_114.tall_3.png és: patologic
# La classe predita per a la imatge 0_Case_114.tall_4.png és: normal
# La classe predita per a la imatge 0_Case_114.tall_5.png és: patologic
# La classe predita per a la imatge 0_Case_114.tall_6.png és: patologic
# La classe predita per a la imatge 0_Case_103.tall_0.png és: patologic
# La classe predita per a la imatge 0_Case_103.tall_2.png és: patologic
# La classe predita per a la imatge 0_Case_103.tall_1.png és: patologic
# La classe predita per a la imatge 0_Case_103.tall_3.png és: patologic
# La classe predita per a la imatge 0_Case_103.tall_4.png és: patologic
# La classe predita per a la imatge 0_Case_103.tall_5.png és: patologic
# La classe predita per a la imatge 0_Case_141.tall_0.png és: patologic
# La classe predita per a la imatge 0_Case_141.tall_1.png és: patologic
# La classe predita per a la imatge 0_Case_141.tall_3.png és: normal
# La classe predita per a la imatge 0_Case_141.tall_4.png és: patologic
# La classe predita per a la imatge 0_Case_141.tall_2.png és: patologic
# La classe predita per a la imatge 0_Case_141.tall_6.png és: patologic
# La classe predita per a la imatge 0_Case_141.tall_5.png és: patologic
# La classe predita per a la imatge 0_Case_132.tall_0.png és: patologic
# La classe predita per a la imatge 0_Case_132.tall_1.png és: patologic
# La classe predita per a la imatge 0_Case_132.tall_2.png és: patologic
# La classe predita per a la imatge 0_Case_132.tall_3.png és: patologic
# La classe predita per a la imatge 0_Case_132.tall_4.png és: patologic
# La classe predita per a la imatge 0_Case_132.tall_5.png és: patologic
# La classe predita per a la imatge 0_Case_123.tall_0.png és: normal
# La classe predita per a la imatge 0_Case_123.tall_1.png és: normal
# La classe predita per a la imatge 0_Case_123.tall_2.png és: normal
# La classe predita per a la imatge 0_Case_123.tall_3.png és: normal
# La classe predita per a la imatge 0_Case_123.tall_4.png és: normal
# La classe predita per a la imatge 0_Case_123.tall_5.png és: patologic
# La classe predita per a la imatge 0_Case_123.tall_6.png és: normal
# La classe predita per a la imatge 0_Case_123.tall_7.png és: normal
# La classe predita per a la imatge 0_Case_150.tall_0.png és: patologic
# La classe predita per a la imatge 0_Case_150.tall_1.png és: patologic
# La classe predita per a la imatge 0_Case_150.tall_3.png és: normal
# La classe predita per a la imatge 0_Case_150.tall_2.png és: normal
# La classe predita per a la imatge 0_Case_150.tall_4.png és: normal
# La classe predita per a la imatge 0_Case_150.tall_6.png és: normal
# La classe predita per a la imatge 0_Case_150.tall_5.png és: normal
# La classe predita per a la imatge 0_Case_142.tall_0.png és: patologic
# La classe predita per a la imatge 0_Case_142.tall_1.png és: patologic
# La classe predita per a la imatge 0_Case_142.tall_3.png és: patologic
# La classe predita per a la imatge 0_Case_142.tall_2.png és: patologic
# La classe predita per a la imatge 0_Case_142.tall_4.png és: patologic
# La classe predita per a la imatge 0_Case_142.tall_5.png és: patologic
# La classe predita per a la imatge 0_Case_142.tall_6.png és: patologic
# La classe predita per a la imatge 0_Case_142.tall_7.png és: patologic
# La classe predita per a la imatge 0_Case_128.tall_0.png és: patologic
# La classe predita per a la imatge 0_Case_128.tall_2.png és: patologic
# La classe predita per a la imatge 0_Case_128.tall_3.png és: patologic
# La classe predita per a la imatge 0_Case_128.tall_4.png és: normal
# La classe predita per a la imatge 0_Case_128.tall_1.png és: patologic
# La classe predita per a la imatge 0_Case_128.tall_5.png és: normal
# La classe predita per a la imatge 0_Case_128.tall_6.png és: normal
# La classe predita per a la imatge 0_Case_107.tall_0.png és: patologic
# La classe predita per a la imatge 0_Case_107.tall_1.png és: patologic
# La classe predita per a la imatge 0_Case_107.tall_2.png és: patologic
# La classe predita per a la imatge 0_Case_107.tall_3.png és: patologic
# La classe predita per a la imatge 0_Case_107.tall_4.png és: patologic
# La classe predita per a la imatge 0_Case_107.tall_5.png és: patologic
# La classe predita per a la imatge 0_Case_107.tall_6.png és: patologic
# La classe predita per a la imatge 0_Case_110.tall_0.png és: patologic
# La classe predita per a la imatge 0_Case_110.tall_1.png és: patologic
# La classe predita per a la imatge 0_Case_110.tall_3.png és: patologic
# La classe predita per a la imatge 0_Case_110.tall_2.png és: patologic
# La classe predita per a la imatge 0_Case_110.tall_4.png és: patologic
# La classe predita per a la imatge 0_Case_110.tall_6.png és: patologic
# La classe predita per a la imatge 0_Case_110.tall_5.png és: patologic
# La classe predita per a la imatge 0_Case_110.tall_7.png és: patologic
# La classe predita per a la imatge 0_Case_139.tall_0.png és: patologic
# La classe predita per a la imatge 0_Case_139.tall_1.png és: patologic
# La classe predita per a la imatge 0_Case_139.tall_2.png és: patologic
# La classe predita per a la imatge 0_Case_139.tall_3.png és: normal
# La classe predita per a la imatge 0_Case_139.tall_4.png és: patologic
# La classe predita per a la imatge 0_Case_146.tall_0.png és: patologic
# La classe predita per a la imatge 0_Case_146.tall_1.png és: patologic
# La classe predita per a la imatge 0_Case_146.tall_2.png és: patologic
# La classe predita per a la imatge 0_Case_146.tall_5.png és: patologic
# La classe predita per a la imatge 0_Case_146.tall_3.png és: patologic
# La classe predita per a la imatge 0_Case_146.tall_4.png és: patologic
# La classe predita per a la imatge 0_Case_116.tall_0.png és: patologic
# La classe predita per a la imatge 0_Case_116.tall_1.png és: patologic
# La classe predita per a la imatge 0_Case_116.tall_2.png és: patologic
# La classe predita per a la imatge 0_Case_116.tall_5.png és: patologic
# La classe predita per a la imatge 0_Case_116.tall_4.png és: patologic
# La classe predita per a la imatge 0_Case_116.tall_3.png és: patologic
# La classe predita per a la imatge 0_Case_101.tall_0.png és: patologic
# La classe predita per a la imatge 0_Case_101.tall_1.png és: patologic
# La classe predita per a la imatge 0_Case_101.tall_2.png és: patologic
# La classe predita per a la imatge 0_Case_101.tall_3.png és: patologic
# La classe predita per a la imatge 0_Case_101.tall_4.png és: patologic
# La classe predita per a la imatge 0_Case_101.tall_6.png és: patologic
# La classe predita per a la imatge 0_Case_101.tall_5.png és: normal
# La classe predita per a la imatge 0_Case_101.tall_7.png és: normal
# La classe predita per a la imatge 0_Case_133.tall_0.png és: normal
# La classe predita per a la imatge 0_Case_133.tall_1.png és: normal
# La classe predita per a la imatge 0_Case_133.tall_2.png és: normal
# La classe predita per a la imatge 0_Case_133.tall_3.png és: normal
# La classe predita per a la imatge 0_Case_133.tall_5.png és: normal
# La classe predita per a la imatge 0_Case_133.tall_4.png és: normal
# La classe predita per a la imatge 0_Case_104.tall_0.png és: normal
# La classe predita per a la imatge 0_Case_104.tall_1.png és: normal
# La classe predita per a la imatge 0_Case_104.tall_2.png és: normal
# La classe predita per a la imatge 0_Case_104.tall_3.png és: normal
# La classe predita per a la imatge 0_Case_104.tall_4.png és: normal
# La classe predita per a la imatge 0_Case_104.tall_5.png és: normal
# La classe predita per a la imatge 0_Case_136.tall_0.png és: normal
# La classe predita per a la imatge 0_Case_136.tall_1.png és: normal
# La classe predita per a la imatge 0_Case_136.tall_2.png és: normal
# La classe predita per a la imatge 0_Case_136.tall_3.png és: normal
# La classe predita per a la imatge 0_Case_136.tall_4.png és: normal
# La classe predita per a la imatge 0_Case_136.tall_5.png és: normal
# La classe predita per a la imatge 0_Case_136.tall_6.png és: normal
# La classe predita per a la imatge 0_Case_136.tall_7.png és: normal
# La classe predita per a la imatge 0_Case_122.tall_0.png és: patologic
# La classe predita per a la imatge 0_Case_122.tall_1.png és: patologic
# La classe predita per a la imatge 0_Case_122.tall_2.png és: patologic
# La classe predita per a la imatge 0_Case_122.tall_3.png és: normal
# La classe predita per a la imatge 0_Case_122.tall_4.png és: patologic
# La classe predita per a la imatge 0_Case_122.tall_5.png és: normal
# La classe predita per a la imatge 0_Case_130.tall_0.png és: patologic
# La classe predita per a la imatge 0_Case_130.tall_1.png és: normal
# La classe predita per a la imatge 0_Case_130.tall_2.png és: patologic
# La classe predita per a la imatge 0_Case_130.tall_3.png és: patologic
# La classe predita per a la imatge 0_Case_130.tall_4.png és: patologic
# La classe predita per a la imatge 0_Case_130.tall_5.png és: patologic
# La classe predita per a la imatge 0_Case_130.tall_6.png és: patologic
# La classe predita per a la imatge 0_Case_120.tall_0.png és: patologic
# La classe predita per a la imatge 0_Case_120.tall_1.png és: patologic
# La classe predita per a la imatge 0_Case_120.tall_2.png és: patologic
# La classe predita per a la imatge 0_Case_120.tall_4.png és: patologic
# La classe predita per a la imatge 0_Case_120.tall_3.png és: patologic
# La classe predita per a la imatge 0_Case_120.tall_5.png és: patologic
# La classe predita per a la imatge 0_Case_120.tall_6.png és: patologic
# La classe predita per a la imatge 0_Case_126.tall_0.png és: patologic
# La classe predita per a la imatge 0_Case_126.tall_2.png és: patologic
# La classe predita per a la imatge 0_Case_126.tall_1.png és: patologic
# La classe predita per a la imatge 0_Case_126.tall_3.png és: patologic
# La classe predita per a la imatge 0_Case_126.tall_4.png és: patologic
# La classe predita per a la imatge 0_Case_126.tall_5.png és: patologic
# La classe predita per a la imatge 0_Case_126.tall_7.png és: patologic
# La classe predita per a la imatge 0_Case_126.tall_6.png és: patologic
# La classe predita per a la imatge 0_Case_131.tall_0.png és: normal
# La classe predita per a la imatge 0_Case_131.tall_1.png és: normal
# La classe predita per a la imatge 0_Case_131.tall_2.png és: normal
# La classe predita per a la imatge 0_Case_131.tall_3.png és: patologic
# La classe predita per a la imatge 0_Case_131.tall_4.png és: normal
# La classe predita per a la imatge 0_Case_131.tall_5.png és: normal
# La classe predita per a la imatge 0_Case_131.tall_6.png és: normal
# La classe predita per a la imatge 0_Case_121.tall_0.png és: normal
# La classe predita per a la imatge 0_Case_121.tall_2.png és: normal
# La classe predita per a la imatge 0_Case_121.tall_3.png és: normal
# La classe predita per a la imatge 0_Case_121.tall_1.png és: normal
# La classe predita per a la imatge 0_Case_121.tall_4.png és: normal
# La classe predita per a la imatge 0_Case_121.tall_5.png és: patologic
# La classe predita per a la imatge 0_Case_121.tall_6.png és: patologic
# La classe predita per a la imatge 0_Case_129.tall_0.png és: patologic
# La classe predita per a la imatge 0_Case_129.tall_1.png és: patologic
# La classe predita per a la imatge 0_Case_129.tall_3.png és: patologic
# La classe predita per a la imatge 0_Case_129.tall_2.png és: patologic
# La classe predita per a la imatge 0_Case_129.tall_4.png és: patologic
# La classe predita per a la imatge 0_Case_129.tall_6.png és: patologic
# La classe predita per a la imatge 0_Case_129.tall_5.png és: patologic
# La classe predita per a la imatge 0_Case_129.tall_7.png és: patologic
# La classe predita per a la imatge 0_Case_125.tall_0.png és: patologic
# La classe predita per a la imatge 0_Case_125.tall_2.png és: patologic
# La classe predita per a la imatge 0_Case_125.tall_1.png és: patologic
# La classe predita per a la imatge 0_Case_125.tall_4.png és: patologic
# La classe predita per a la imatge 0_Case_125.tall_5.png és: patologic
# La classe predita per a la imatge 0_Case_125.tall_3.png és: patologic
# La classe predita per a la imatge 0_Case_117.tall_0.png és: patologic
# La classe predita per a la imatge 0_Case_117.tall_1.png és: patologic
# La classe predita per a la imatge 0_Case_117.tall_2.png és: patologic
# La classe predita per a la imatge 0_Case_117.tall_3.png és: patologic
# La classe predita per a la imatge 0_Case_117.tall_4.png és: patologic
# La classe predita per a la imatge 0_Case_117.tall_5.png és: patologic
# La classe predita per a la imatge 0_Case_119.tall_0.png és: normal
# La classe predita per a la imatge 0_Case_119.tall_1.png és: patologic
# La classe predita per a la imatge 0_Case_119.tall_2.png és: patologic
# La classe predita per a la imatge 0_Case_119.tall_3.png és: patologic
# La classe predita per a la imatge 0_Case_119.tall_4.png és: normal
# La classe predita per a la imatge 0_Case_119.tall_5.png és: patologic
# La classe predita per a la imatge 0_Case_119.tall_6.png és: normal
# La classe predita per a la imatge 0_Case_119.tall_7.png és: patologic
# La classe predita per a la imatge 0_Case_119.tall_8.png és: patologic
# La classe predita per a la imatge 0_Case_127.tall_0.png és: patologic
# La classe predita per a la imatge 0_Case_127.tall_1.png és: patologic
# La classe predita per a la imatge 0_Case_127.tall_3.png és: patologic
# La classe predita per a la imatge 0_Case_127.tall_5.png és: patologic
# La classe predita per a la imatge 0_Case_127.tall_2.png és: patologic
# La classe predita per a la imatge 0_Case_127.tall_4.png és: patologic
# La classe predita per a la imatge 0_Case_127.tall_6.png és: patologic
# La classe predita per a la imatge 0_Case_105.tall_2.png és: patologic
# La classe predita per a la imatge 0_Case_105.tall_0.png és: patologic
# La classe predita per a la imatge 0_Case_105.tall_1.png és: patologic
# La classe predita per a la imatge 0_Case_105.tall_3.png és: patologic
# La classe predita per a la imatge 0_Case_105.tall_5.png és: patologic
# La classe predita per a la imatge 0_Case_105.tall_4.png és: patologic
# La classe predita per a la imatge 0_Case_105.tall_6.png és: patologic
# La classe predita per a la imatge 0_Case_105.tall_8.png és: patologic
# La classe predita per a la imatge 0_Case_105.tall_7.png és: patologic
# La classe predita per a la imatge 0_Case_115.tall_0.png és: patologic
# La classe predita per a la imatge 0_Case_115.tall_1.png és: patologic
# La classe predita per a la imatge 0_Case_115.tall_2.png és: patologic
# La classe predita per a la imatge 0_Case_115.tall_3.png és: patologic
# La classe predita per a la imatge 0_Case_115.tall_4.png és: patologic
# La classe predita per a la imatge 0_Case_115.tall_5.png és: patologic
# La classe predita per a la imatge 0_Case_147.tall_0.png és: patologic
# La classe predita per a la imatge 0_Case_147.tall_1.png és: patologic
# La classe predita per a la imatge 0_Case_147.tall_2.png és: patologic
# La classe predita per a la imatge 0_Case_147.tall_3.png és: patologic
# La classe predita per a la imatge 0_Case_147.tall_4.png és: patologic
# La classe predita per a la imatge 0_Case_147.tall_5.png és: patologic
# La classe predita per a la imatge 0_Case_147.tall_6.png és: patologic
# La classe predita per a la imatge 0_Case_147.tall_7.png és: patologic
# La classe predita per a la imatge 0_Case_102.tall_0.png és: normal
# La classe predita per a la imatge 0_Case_102.tall_1.png és: normal
# La classe predita per a la imatge 0_Case_102.tall_3.png és: normal
# La classe predita per a la imatge 0_Case_102.tall_2.png és: normal
# La classe predita per a la imatge 0_Case_102.tall_4.png és: normal
# La classe predita per a la imatge 0_Case_102.tall_5.png és: normal
# La classe predita per a la imatge 0_Case_134.tall_0.png és: normal
# La classe predita per a la imatge 0_Case_134.tall_3.png és: patologic
# La classe predita per a la imatge 0_Case_134.tall_1.png és: patologic
# La classe predita per a la imatge 0_Case_134.tall_2.png és: patologic
# La classe predita per a la imatge 0_Case_134.tall_4.png és: patologic
# La classe predita per a la imatge 0_Case_134.tall_5.png és: patologic
# La classe predita per a la imatge 0_Case_145.tall_1.png és: normal
# La classe predita per a la imatge 0_Case_145.tall_0.png és: normal
# La classe predita per a la imatge 0_Case_145.tall_2.png és: normal
# La classe predita per a la imatge 0_Case_145.tall_3.png és: normal
# La classe predita per a la imatge 0_Case_145.tall_5.png és: normal
# La classe predita per a la imatge 0_Case_145.tall_4.png és: normal
# La classe predita per a la imatge 0_Case_145.tall_6.png és: normal
# La classe predita per a la imatge 0_Case_140.tall_1.png és: patologic
# La classe predita per a la imatge 0_Case_140.tall_0.png és: patologic
# La classe predita per a la imatge 0_Case_140.tall_2.png és: patologic
# La classe predita per a la imatge 0_Case_140.tall_3.png és: normal
# La classe predita per a la imatge 0_Case_140.tall_5.png és: patologic
# La classe predita per a la imatge 0_Case_140.tall_6.png és: normal
# La classe predita per a la imatge 0_Case_140.tall_4.png és: normal
# La classe predita per a la imatge 0_Case_140.tall_7.png és: patologic
# La classe predita per a la imatge 0_Case_140.tall_8.png és: normal
# La classe predita per a la imatge 0_Case_108.tall_1.png és: patologic
# La classe predita per a la imatge 0_Case_108.tall_0.png és: patologic
# La classe predita per a la imatge 0_Case_108.tall_2.png és: patologic
# La classe predita per a la imatge 0_Case_108.tall_3.png és: patologic
# La classe predita per a la imatge 0_Case_108.tall_4.png és: patologic
# La classe predita per a la imatge 0_Case_108.tall_5.png és: patologic
# La classe predita per a la imatge 0_Case_108.tall_6.png és: patologic
# La classe predita per a la imatge 0_Case_138.tall_0.png és: normal
# La classe predita per a la imatge 0_Case_138.tall_1.png és: normal
# La classe predita per a la imatge 0_Case_138.tall_2.png és: normal
# La classe predita per a la imatge 0_Case_138.tall_3.png és: normal
# La classe predita per a la imatge 0_Case_138.tall_4.png és: normal
# La classe predita per a la imatge 0_Case_138.tall_5.png és: normal
# La classe predita per a la imatge 0_Case_138.tall_6.png és: normal
# La classe predita per a la imatge 0_Case_138.tall_7.png és: normal
# La classe predita per a la imatge 0_Case_124.tall_0.png és: normal
# La classe predita per a la imatge 0_Case_124.tall_2.png és: patologic
# La classe predita per a la imatge 0_Case_124.tall_1.png és: normal
# La classe predita per a la imatge 0_Case_124.tall_4.png és: normal
# La classe predita per a la imatge 0_Case_124.tall_3.png és: patologic
# La classe predita per a la imatge 0_Case_124.tall_5.png és: normal
# La classe predita per a la imatge 0_Case_124.tall_6.png és: normal
# La classe predita per a la imatge 0_Case_124.tall_7.png és: patologic
# La classe predita per a la imatge 0_Case_109.tall_0.png és: patologic
# La classe predita per a la imatge 0_Case_109.tall_1.png és: patologic
# La classe predita per a la imatge 0_Case_109.tall_2.png és: patologic
# La classe predita per a la imatge 0_Case_109.tall_3.png és: patologic
# La classe predita per a la imatge 0_Case_109.tall_4.png és: patologic
# La classe predita per a la imatge 0_Case_109.tall_5.png és: patologic
# La classe predita per a la imatge 0_Case_109.tall_7.png és: patologic
# La classe predita per a la imatge 0_Case_109.tall_6.png és: patologic
# La classe predita per a la imatge 0_Case_135.tall_0.png és: patologic
# La classe predita per a la imatge 0_Case_135.tall_1.png és: patologic
# La classe predita per a la imatge 0_Case_135.tall_4.png és: patologic
# La classe predita per a la imatge 0_Case_135.tall_2.png és: patologic
# La classe predita per a la imatge 0_Case_135.tall_3.png és: patologic
# La classe predita per a la imatge 0_Case_135.tall_5.png és: patologic
# La classe predita per a la imatge 0_Case_112.tall_0.png és: patologic
# La classe predita per a la imatge 0_Case_112.tall_1.png és: patologic
# La classe predita per a la imatge 0_Case_112.tall_2.png és: patologic
# La classe predita per a la imatge 0_Case_112.tall_4.png és: patologic
# La classe predita per a la imatge 0_Case_112.tall_3.png és: patologic
# La classe predita per a la imatge 0_Case_112.tall_5.png és: patologic
# La classe predita per a la imatge 0_Case_118.tall_0.png és: patologic
# La classe predita per a la imatge 0_Case_118.tall_1.png és: patologic
# La classe predita per a la imatge 0_Case_118.tall_2.png és: patologic
# La classe predita per a la imatge 0_Case_118.tall_3.png és: patologic
# La classe predita per a la imatge 0_Case_118.tall_4.png és: patologic
# La classe predita per a la imatge 0_Case_118.tall_5.png és: patologic
# La classe predita per a la imatge 0_Case_118.tall_6.png és: patologic
# La classe predita per a la imatge 0_Case_118.tall_7.png és: patologic
# La classe predita per a la imatge 0_Case_118.tall_8.png és: patologic
# La classe predita per a la imatge 0_Case_143.tall_0.png és: patologic
# La classe predita per a la imatge 0_Case_143.tall_1.png és: patologic
# La classe predita per a la imatge 0_Case_143.tall_2.png és: normal
# La classe predita per a la imatge 0_Case_143.tall_3.png és: patologic
# La classe predita per a la imatge 0_Case_143.tall_4.png és: patologic
# La classe predita per a la imatge 0_Case_143.tall_5.png és: patologic
# La classe predita per a la imatge 0_Case_143.tall_6.png és: patologic
# La classe predita per a la imatge 0_Case_111.tall_1.png és: normal
# La classe predita per a la imatge 0_Case_111.tall_2.png és: normal
# La classe predita per a la imatge 0_Case_111.tall_0.png és: normal
# La classe predita per a la imatge 0_Case_111.tall_4.png és: normal
# La classe predita per a la imatge 0_Case_111.tall_3.png és: normal
# La classe predita per a la imatge 0_Case_111.tall_6.png és: normal
# La classe predita per a la imatge 0_Case_111.tall_5.png és: normal

# %%
# Crear un diccionari per a agrupar les classificacions per num_cas
classificacions_agrupades = {}

# Imprimir les classes predites per a cada imatge a la carpeta de prova i agrupar-les per num_cas
for i in range(matriu_imatges_test.shape[0]):
    nom_fitxer = os.path.basename(noms_fitxers[i])
    classe_predita = classes_predites[i]
   
    if classe_predita == 0:
        classe = 'normal'
    else:
        classe = 'patològic'
    
    # Obtindre el num_cas de la imatge
    num_cas = nom_fitxer.split('.')[0]
    
    # Afegir la classificació al diccionari
    if num_cas in classificacions_agrupades:
        classificacions_agrupades[num_cas].append(classe)
    else:
        classificacions_agrupades[num_cas] = [classe]


# Imprimir les classificacions agrupades i verificar si són totes iguals per a considerar-les correctes
for num_cas, classificacions in classificacions_agrupades.items():
    # Verificar si totes les classificacions són iguals
    if all(classificacio == classificacions[0] for classificacio in classificacions):
        print(f"{num_cas}     té classificació:                 {classificacions[0]}")
    else:
        print(f"{num_cas}     té classificacions diferents:     {classificacions}")


# Crear una llista de files per la taula
tabla_filas = []
for num_cas, classificacions in classificacions_agrupades.items():
    if all(classificacio == classificacions[0] for classificacio in classificacions):
        tabla_filas.append([num_cas, classificacions[0]])
    else:
        tabla_filas.append([num_cas, "Diferents"] + classificacions)

# Imprimir la taula
headers = ["num_cas", "classificació"]
tabla = tabulate(tabla_filas, headers, tablefmt="grid")
print(tabla)
# Out:
# 0_Case_113     té classificació:                 normal
# 0_Case_137     té classificació:                 patològic
# 0_Case_106     té classificacions diferents:     ['normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'normal', 'patològic']
# 0_Case_114     té classificacions diferents:     ['patològic', 'patològic', 'patològic', 'patològic', 'normal', 'patològic', 'patològic']
# 0_Case_103     té classificació:                 patològic
# 0_Case_141     té classificacions diferents:     ['patològic', 'patològic', 'normal', 'patològic', 'patològic', 'patològic', 'patològic']
# 0_Case_132     té classificació:                 patològic
# 0_Case_123     té classificacions diferents:     ['normal', 'normal', 'normal', 'normal', 'normal', 'patològic', 'normal', 'normal']
# 0_Case_150     té classificacions diferents:     ['patològic', 'patològic', 'normal', 'normal', 'normal', 'normal', 'normal']
# 0_Case_142     té classificació:                 patològic
# 0_Case_128     té classificacions diferents:     ['patològic', 'patològic', 'patològic', 'normal', 'patològic', 'normal', 'normal']
# 0_Case_107     té classificació:                 patològic
# 0_Case_110     té classificació:                 patològic
# 0_Case_139     té classificacions diferents:     ['patològic', 'patològic', 'patològic', 'normal', 'patològic']
# 0_Case_146     té classificació:                 patològic
# 0_Case_116     té classificació:                 patològic
# 0_Case_101     té classificacions diferents:     ['patològic', 'patològic', 'patològic', 'patològic', 'patològic', 'patològic', 'normal', 'normal']
# 0_Case_133     té classificació:                 normal
# 0_Case_104     té classificació:                 normal
# 0_Case_136     té classificació:                 normal
# 0_Case_122     té classificacions diferents:     ['patològic', 'patològic', 'patològic', 'normal', 'patològic', 'normal']
# 0_Case_130     té classificacions diferents:     ['patològic', 'normal', 'patològic', 'patològic', 'patològic', 'patològic', 'patològic']
# 0_Case_120     té classificació:                 patològic
# 0_Case_126     té classificació:                 patològic
# 0_Case_131     té classificacions diferents:     ['normal', 'normal', 'normal', 'patològic', 'normal', 'normal', 'normal']
# 0_Case_121     té classificacions diferents:     ['normal', 'normal', 'normal', 'normal', 'normal', 'patològic', 'patològic']
# 0_Case_129     té classificació:                 patològic
# 0_Case_125     té classificació:                 patològic
# 0_Case_117     té classificació:                 patològic
# 0_Case_119     té classificacions diferents:     ['normal', 'patològic', 'patològic', 'patològic', 'normal', 'patològic', 'normal', 'patològic', 'patològic']
# 0_Case_127     té classificació:                 patològic
# 0_Case_105     té classificació:                 patològic
# 0_Case_115     té classificació:                 patològic
# 0_Case_147     té classificació:                 patològic
# 0_Case_102     té classificació:                 normal
# 0_Case_134     té classificacions diferents:     ['normal', 'patològic', 'patològic', 'patològic', 'patològic', 'patològic']
# 0_Case_145     té classificació:                 normal
# 0_Case_140     té classificacions diferents:     ['patològic', 'patològic', 'patològic', 'normal', 'patològic', 'normal', 'normal', 'patològic', 'normal']
# 0_Case_108     té classificació:                 patològic
# 0_Case_138     té classificació:                 normal
# 0_Case_124     té classificacions diferents:     ['normal', 'patològic', 'normal', 'normal', 'patològic', 'normal', 'normal', 'patològic']
# 0_Case_109     té classificació:                 patològic
# 0_Case_135     té classificació:                 patològic
# 0_Case_112     té classificació:                 patològic
# 0_Case_118     té classificació:                 patològic
# 0_Case_143     té classificacions diferents:     ['patològic', 'patològic', 'normal', 'patològic', 'patològic', 'patològic', 'patològic']
# 0_Case_111     té classificació:                 normal
# +------------+-----------------+
# | num_cas    | classificació   |
# +============+=================+
# | 0_Case_113 | normal          |
# +------------+-----------------+
# | 0_Case_137 | patològic       |
# +------------+-----------------+
# | 0_Case_106 | Diferents       |
# +------------+-----------------+
# | 0_Case_114 | Diferents       |
# +------------+-----------------+
# | 0_Case_103 | patològic       |
# +------------+-----------------+
# | 0_Case_141 | Diferents       |
# +------------+-----------------+
# | 0_Case_132 | patològic       |
# +------------+-----------------+
# | 0_Case_123 | Diferents       |
# +------------+-----------------+
# | 0_Case_150 | Diferents       |
# +------------+-----------------+
# | 0_Case_142 | patològic       |
# +------------+-----------------+
# | 0_Case_128 | Diferents       |
# +------------+-----------------+
# | 0_Case_107 | patològic       |
# +------------+-----------------+
# | 0_Case_110 | patològic       |
# +------------+-----------------+
# | 0_Case_139 | Diferents       |
# +------------+-----------------+
# | 0_Case_146 | patològic       |
# +------------+-----------------+
# | 0_Case_116 | patològic       |
# +------------+-----------------+
# | 0_Case_101 | Diferents       |
# +------------+-----------------+
# | 0_Case_133 | normal          |
# +------------+-----------------+
# | 0_Case_104 | normal          |
# +------------+-----------------+
# | 0_Case_136 | normal          |
# +------------+-----------------+
# | 0_Case_122 | Diferents       |
# +------------+-----------------+
# | 0_Case_130 | Diferents       |
# +------------+-----------------+
# | 0_Case_120 | patològic       |
# +------------+-----------------+
# | 0_Case_126 | patològic       |
# +------------+-----------------+
# | 0_Case_131 | Diferents       |
# +------------+-----------------+
# | 0_Case_121 | Diferents       |
# +------------+-----------------+
# | 0_Case_129 | patològic       |
# +------------+-----------------+
# | 0_Case_125 | patològic       |
# +------------+-----------------+
# | 0_Case_117 | patològic       |
# +------------+-----------------+
# | 0_Case_119 | Diferents       |
# +------------+-----------------+
# | 0_Case_127 | patològic       |
# +------------+-----------------+
# | 0_Case_105 | patològic       |
# +------------+-----------------+
# | 0_Case_115 | patològic       |
# +------------+-----------------+
# | 0_Case_147 | patològic       |
# +------------+-----------------+
# | 0_Case_102 | normal          |
# +------------+-----------------+
# | 0_Case_134 | Diferents       |
# +------------+-----------------+
# | 0_Case_145 | normal          |
# +------------+-----------------+
# | 0_Case_140 | Diferents       |
# +------------+-----------------+
# | 0_Case_108 | patològic       |
# +------------+-----------------+
# | 0_Case_138 | normal          |
# +------------+-----------------+
# | 0_Case_124 | Diferents       |
# +------------+-----------------+
# | 0_Case_109 | patològic       |
# +------------+-----------------+
# | 0_Case_135 | patològic       |
# +------------+-----------------+
# | 0_Case_112 | patològic       |
# +------------+-----------------+
# | 0_Case_118 | patològic       |
# +------------+-----------------+
# | 0_Case_143 | Diferents       |
# +------------+-----------------+
# | 0_Case_111 | normal          |
# +------------+-----------------+
